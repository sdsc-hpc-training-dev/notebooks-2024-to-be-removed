# %% [markdown]
# # Hello World
#
# No package dependencies

# %%
print('Hello world!!!!')
# Out:
# Hello world!!!!

# %%
# Import hello module
import hello

# Define a function
def world2(name):
    print(name)

# %%
# Call function
world2("mary")
# Out:
# mary

# %%
hello.greeting("good times")
# Out:
# Greetings, good times

# %%
hello.world("World.")
# Out:
# Hello, World.
